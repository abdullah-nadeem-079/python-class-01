# %% [markdown]
# ## Topics covered in Python:
# * Print Function
# * Operators and Data types
# * Variables
#     * Rules for naming variables
# * Strings
#     * Basic string operations
#     * Strings functions
#     * Concatenation
#     * f-string
# * Conditional Statements
#     * if statement
#     * elif statement
#     * else statement
#     * Nested Conditional Statements
# * Data Structures
#     * Lists
#         * Basic list operations
#         * List functions
#     * Dictionary
#         * Basic Dictionary operations
#         * Dictionary functions
#     * Tuple
#         * Basic Touple operations
#         * Tuple functions
#     * Set
#         * Basic Set operations
#         * Set functions
# * Loops in Python
#     * for in loop
#         * Iterating over differnet data structures using for in loop
#         * Conditional statements in for in loop
#         * Control Statements in for in loop
#     * While loop
#         * Iterating over differnet data structures using while loop
#         * Conditional statements in while loop
#         * Control Statements in while loop
# * Functions in python
#     * Built-in functions
#     * Class functions
#     * User-defined functions
#     * Local Variables in functions
#     * Return Statement in functions
#     * Function overloading in python
#     * Arbitrary number of arguments
#     * Positional arguments and Keyword arguments
#     * Default parameter values
# * File read and write | Input output operations
#     * Open function
#     * Context manager function
# * Error handling in python
#     * Different types of errors
#     * try : except, else, finally (keywords)
#     * Exception class
#     * User-defined exceptions
#     * Object-blueprint calss
# * OOP-Object Oriented Programming
#     * All basic concepts of OOP in detail
#         * class, object, initializer, attributes and methods
#     * OOP Principles
#         * Encapsulation
#         * Abstraction
#         * Inheritance
#         * Polymorphism
#     * Advance concepts of OOP
#         * Types of attributes in OOP
#         * Types of methods in OOP
#         * Multi-level inheritance
#         * Multiple inheritance
#         * Dealing with initializer in inheritanace
#         * Super Keyword
#         * Polymorphism via duck typing
#         * polymorphism via operator overloading
#         * Instance as variable
#         * Generators, Iterators and Decorators (In detail)
